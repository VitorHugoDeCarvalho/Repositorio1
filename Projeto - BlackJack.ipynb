# %%
dinheiro=500
placarJogador=0
placarDealer=0
while True:     
    
    import random
    import sys
    
    hit=False
    valorTotalJogador=0
    valorTotalDealer=0
    cartasJogador=[]
    cartasDealer=[]
    sair=0
    aposta=0
    decisao = ""
    aux=0
    estourou=False


    class Carta:
        def __init__(self, valor):
            self.valor = valor
        def __str__(self):
            return str(self.valor)
    dois = Carta(2)   
    tres = Carta(3)   
    quatro = Carta(4)   
    cinco = Carta(5)   
    seis = Carta(6)   
    sete = Carta(7)   
    oito = Carta(8)   
    nove = Carta(9)   
    dez = Carta(10)   

    #valete = Carta(10)   
    #dama = Carta(10)   
    #rei = Carta(10)
    valeteDamaRei=Carta(10)
    As = Carta(11)     

    baralho=[]
    baralho.append(dois.valor)
    baralho.append(tres.valor)
    baralho.append(quatro.valor)
    baralho.append(cinco.valor)
    baralho.append(seis.valor)
    baralho.append(sete.valor)
    baralho.append(oito.valor)
    baralho.append(nove.valor)
    baralho.append(dez.valor)
    baralho.append(valeteDamaRei.valor)
    baralho.append(valeteDamaRei.valor)
    baralho.append(valeteDamaRei.valor)
    baralho.append(As.valor)

    baralho= baralho*4
    random.shuffle(baralho)

    cartasJogador.append(baralho.pop())
    cartasJogador.append(baralho.pop())
    valorTotalJogador=cartasJogador[0] + cartasJogador[1]

    cartasDealer.append(baralho.pop())
    cartasDealer.append(baralho.pop())
    valorTotalDealer=cartasDealer[0] + cartasDealer[1]

    if (cartasJogador[0]== 11) and cartasJogador[0] + cartasJogador[1] > 21:
        cartasJogador[0]=1
    elif (cartasJogador[1]== 11) and cartasJogador[0] + cartasJogador[1] > 21:
        cartasJogador[1]=1
    else:
        pass

    if (valorTotalDealer + 11) > 21:
        As=Carta(1)
    else:
        As=Carta(11)

    #----------------------------------------------------------------------------------------------------------------    
    print("Bem vindo ao blackjack")
    print("Dinheiro:",dinheiro)
    print("Placar do jogador:",placarJogador)
    print("Placar do Dealer:",placarDealer)
    print("----------------------------------------------------")
    
    while True:
        aposta=int(input("Quanto quer apostar?\n"))
        aposta=aposta+10

        if aposta > dinheiro:
            print("Você não pode apostar mais do que tem")
            
        else:
            dinheiro = dinheiro - aposta
            print("Dinheiro disponivel:",dinheiro)
            print("Dinheiro apostado:", aposta)
            print("----------------------------------------------------")
            break

    finalizado=False    
    while not finalizado:    
        while True: 
            
            aux=0
            decisao=2
            blackjack=0

            print("Cartas do jogador:",cartasJogador)
            print("Cartas do Dealer:",cartasDealer[0],",","?""\n")
            print("Valor total das cartas:",valorTotalJogador)
            print("----------------------------------------------------")
            #ESTOURO do jogador
            if valorTotalJogador > 21:
                placarDealer=placarDealer+1
                print("Cartas do jogador:",cartasJogador)
                print("Cartas do Dealer:",cartasDealer[0],",","?""\n")
                valorTotalJogador=aux+ cartasJogador[-1]
                print("Jogador Estourou!") 
                estourou=True
                finalizado=True 
                break
            #Caso tenha BLACKJACK do dealer   
            if (cartasDealer[0]== "vdr" and cartasDealer[1] ==11) or (cartasDealer[1]== "vdr" and cartasDealer[0] ==11):
                print("BLACKJACK do DEALER!")
                placarDealer=placarDealer+1
                blackjack=blackjack+1
                 #Caso tenha BLACKJACK do jogador 
                if (cartasJogador[0]== "vdr" and cartasJogador[1] ==11) or (cartasJogador[1]== "vdr" and cartasJogador[0] ==11):
                    print("BLACKJACK do JOGADOR!")
                    placarJogador=placarJogador+1
                    dinheiro=dinheiro + (aposta*2)
                    blackjack=blackjack+1
                    #Caso tenha BLACKJACK dos dois lados
                    if blackjack == 2:
                        placarJogador=placarJogador-1
                        dinheiro=dinheiro - (aposta*2)
                        placarDealer=placarDealer-1
                        print("EMPATOU")
                        break
                       
                    finalizado=True 
                    break
                    
                finalizado=True    
                break                     
            
            #Caso não tenha BLACKJACK transforma vdr em 10
            if (cartasJogador[0]== "vdr" and cartasJogador[1] !=11):
                cartasJogador[0]=10
            if (cartasJogador[1]== "vdr" and cartasJogador[0] !=11):
                cartasJogador[1]=10
            if (cartasDealer[0]== "vdr" and cartasDealer[1] !=11):
                cartasDealer[0]=10
            if (cartasDealer[1]== "vdr" and cartasDealer[0] !=11):
                cartasDealer[1]=10


            #Caso o jogador comece com 21
            if valorTotalJogador == 21:
                finalizado=True
                break
            #Variavel auxiliar que armazena o valor total das cartas do jogador
            for i in range(len(cartasJogador)):
                aux = aux + cartasJogador[i]
            #Caso o jogador tiver a possibilidade de comprar cartas ainda, ou seja, não tem um valor total de 21
            while True:
                if aux <= 20 and not hit:
                    print("Quer comprar uma carta, parar ou dobrar?")
                    decisao =int(input("Digite 1 para comprar, Digite 2 para dobrar ou 0 para parar: "))
                    if decisao==0 or decisao==1 or decisao==2:
                        break
                    else:
                        print("Só pode digitar 0, 1 ou 2!")
                if aux <= 20 and hit==True:
                    print("Quer comprar uma carta, parar?")
                    decisao =int(input("Digite 1 para comprar ou 0 para parar: "))
                    if decisao==0 or decisao==1:
                        break
                    else:
                        print("Só pode digitar 0 ou 1!")
            if decisao==0:
                finalizado=True 
                break
            #Adiciona uma carta do baralho no cartasJogador e armazena o valor total da aux + a ultima carta na variavel ValorTotalJogador    
            if decisao == 1:
                cartasJogador.append(baralho.pop())
                valorTotalJogador=aux+ cartasJogador[-1]
                print("Cartas do jogador:",cartasJogador)
                print("Cartas do Dealer:",cartasDealer[0],",","?""\n")
                print("Valor total das Cartas do jogador:",valorTotalJogador)
                hit=True
                break
            #Dobro    
            if decisao == 2 and hit==False:
                
                cartasJogador.append(baralho.pop())
                dinheiro=dinheiro - aposta
                aposta=aposta*2
                valorTotalJogador=aux+ cartasJogador[-1]
                print("Cartas do jogador:",cartasJogador)
                print("Cartas do Dealer:",cartasDealer[0],",","?""\n")
                print("Valor total das Cartas do jogador:",valorTotalJogador)
                finalizado=True
                break  
                

    #aux=0    

    if not estourou and blackjack==0:
        while True:
            if cartasDealer[0] + cartasDealer[1] >=17:
                break
            #Caso o deck do dealer seja maior que do player
            if valorTotalDealer>valorTotalJogador:
                break
            aux=0
            #Adiciona uma carta do baralho no deck do dealer
            cartasDealer.append(baralho.pop())
            #Variavel auxiliar que armazena o valor total das cartas do dealer
            for i in range(len(cartasDealer)):
                aux= aux + cartasDealer[i]
            #Armazena o valor de aux em valorTotalDealer    
            valorTotalDealer = aux
            print("Cartas do dealer:", cartasDealer)
            print("----------------------------------------------------")
            #Caso o dealer nao estourou mas ainda não ganhou
            if valorTotalDealer + 1<17 and valorTotalDealer <=valorTotalJogador:
                cartasDealer.append(baralho.pop())
                print("Cartas do dealer:", cartasDealer)
                valorTotalDealer=aux+ cartasDealer[-1]
            #aux=0
            #if valorTotalJogador == 21:
                #break

            if valorTotalDealer > 21:
                placarJogador=placarJogador+1
                dinheiro=dinheiro + (aposta*2)
                print("Dealer Estourou")
                print("jogador ganhou!")
                break
    else:
        print("----------------------------------------------------")


    valorTotalDealer=0
    valorTotalJogador=0 
    for i in range(len(cartasDealer)):
        valorTotalDealer= valorTotalDealer + cartasDealer[i]

    for i in range(len(cartasJogador)):
        valorTotalJogador = valorTotalJogador + cartasJogador[i]

    if valorTotalDealer >valorTotalJogador and valorTotalDealer<=21:
        placarDealer=placarDealer+1
        print("Dealer Ganhou!")

    if valorTotalDealer==valorTotalJogador:    
        print("Empatou!")

    if valorTotalDealer<valorTotalJogador and valorTotalJogador<=21:
        placarJogador=placarJogador+1
        dinheiro=dinheiro + (aposta*2)
        print("jogador ganhou!")

    print("----------------------------------------------------")
    print("Cartas do jogador:",cartasJogador,"Valor total das cartas:",valorTotalJogador)
    print("Cartas do dealer:", cartasDealer,"Valor total das cartas:",valorTotalDealer)
    print("----------------------------------------------------")    
    print("Placar jogador:",placarJogador)
    print("Placar Dealer:",placarDealer)
    print("Dinheiro:",dinheiro)
    print("Dinheiro apostado:",aposta)
    print("----------------------------------------------------") 

    reiniciar = input("Deseja jogar novamente? (s/n): ")
    if reiniciar.lower() !="s":
        break
    else:
        print("----------------------------------------------------")
        print("\n"*2)
    if dinheiro <= 0:
        print("Você não tem mais dinheiro! VÁ EMBORA!")
        sys.exit()
# Out:
# Bem vindo ao blackjack
# Dinheiro: 500
# Placar do jogador: 0
# Placar do Dealer: 0
# ----------------------------------------------------
# Quanto quer apostar?
# 1
# Dinheiro disponivel: 489
# Dinheiro apostado: 11
# ----------------------------------------------------
# Cartas do jogador: [11, 6]
# Cartas do Dealer: 10 , ?
#
# Valor total das cartas: 17
# ----------------------------------------------------
# Quer comprar uma carta, parar ou dobrar?
# Digite 1 para comprar, Digite 2 para dobrar ou 0 para parar: 0
# Cartas do dealer: [10, 2, 7]
# ----------------------------------------------------
# Dealer Ganhou!
# ----------------------------------------------------
# Cartas do jogador: [11, 6] Valor total das cartas: 17
# Cartas do dealer: [10, 2, 7] Valor total das cartas: 19
# ----------------------------------------------------
# Placar jogador: 0
# Placar Dealer: 1
# Dinheiro: 489
# Dinheiro apostado: 11
# ----------------------------------------------------
# ...
